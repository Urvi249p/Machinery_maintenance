# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
# Replace 'path_to_dataset.csv' with the actual file path of your dataset
df = pd.read_csv('predictive_maintenance.csv')
#Drop irrelevant columns
df = df.drop(columns=['UDI', 'Product ID'])
#One-hot encode the categorical columns
df = pd.get_dummies(df, columns=['Type', 'Failure Type'], drop_first=True)

# %%
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Air temperature [K]              10000 non-null  float64
#  1   Process temperature [K]          10000 non-null  float64
#  2   Rotational speed [rpm]           10000 non-null  int64
#  3   Torque [Nm]                      10000 non-null  float64
#  4   Tool wear [min]                  10000 non-null  int64
#  5   Target                           10000 non-null  int64
#  6   Type_L                           10000 non-null  uint8
#  7   Type_M                           10000 non-null  uint8
#  8   Failure Type_No Failure          10000 non-null  uint8
#  9   Failure Type_Overstrain Failure  10000 non-null  uint8
#  10  Failure Type_Power Failure       10000 non-null  uint8
#  11  Failure Type_Random Failures     10000 non-null  uint8
# ...

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
# 3                298.2                    308.6                    1433
# 4                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target  Type_L  Type_M  \
# 0         42.8                0       0       0       1
# 1         46.3                3       0       1       0
# 2         49.4                5       0       1       0
# 3         39.5                7       0       1       0
# 4         40.0                9       0       1       0
#
#    Failure Type_No Failure  Failure Type_Overstrain Failure  \
# 0                        1                                0
# 1                        1                                0
# ...

# %%
# Summary statistics of numerical columns
print(df.describe())
# Out:
#        Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# count         10000.000000             10000.000000            10000.000000
# mean            300.004930               310.005560             1538.776100
# std               2.000259                 1.483734              179.284096
# min             295.300000               305.700000             1168.000000
# 25%             298.300000               308.800000             1423.000000
# 50%             300.100000               310.100000             1503.000000
# 75%             301.500000               311.100000             1612.000000
# max             304.500000               313.800000             2886.000000
#
#         Torque [Nm]  Tool wear [min]        Target        Type_L  \
# count  10000.000000     10000.000000  10000.000000  10000.000000
# mean      39.986910       107.951000      0.033900      0.600000
# std        9.968934        63.654147      0.180981      0.489922
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Air temperature [K]                0
# Process temperature [K]            0
# Rotational speed [rpm]             0
# Torque [Nm]                        0
# Tool wear [min]                    0
# Target                             0
# Type_L                             0
# Type_M                             0
# Failure Type_No Failure            0
# Failure Type_Overstrain Failure    0
# Failure Type_Power Failure         0
# Failure Type_Random Failures       0
# Failure Type_Tool Wear Failure     0
# dtype: int64

# %%
# Visualize the distribution of the 'machine failure' label (Target 1)
plt.figure(figsize=(6, 4))
sns.countplot(x='Target', data=df)
plt.title("Distribution of Machine Failure")
plt.xlabel("Machine Failure")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the distribution of the 'Failure Type' label (Target 2)
plt.figure(figsize=(10, 4))
sns.countplot(x='Failure Type_No Failure', data=df)
plt.title("Distribution of Failure Types")
plt.xlabel("Failure Type: No failure")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the distribution of the 'Failure Type' label (Target 2)
plt.figure(figsize=(10, 4))
sns.countplot(x='Failure Type_Overstrain Failure', data=df)
plt.title("Distribution of Failure Types")
plt.xlabel("Failure Type: Overstrain Failure ")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the distribution of the 'Failure Type' label (Target 2)
plt.figure(figsize=(10, 4))
sns.countplot(x='Failure Type_Power Failure', data=df)
plt.title("Distribution of Failure Types")
plt.xlabel("Failure Type: Power Failure")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the distribution of the 'Failure Type' label (Target 2)
plt.figure(figsize=(10, 4))
sns.countplot(x='Failure Type_Random Failures', data=df)
plt.title("Distribution of Failure Types")
plt.xlabel("Failure Type: Random Failures")
plt.ylabel("Count")
plt.show()

# %%
# Visualize the distribution of the 'Failure Type' label (Target 2)
plt.figure(figsize=(10, 4))
sns.countplot(x='Failure Type_Tool Wear Failure', data=df)
plt.title("Distribution of Failure Types")
plt.xlabel("Failure Type: Tool Wear Failure")
plt.ylabel("Count")
plt.show()

# %%
# Correlation heatmap of numerical features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Visualize the relationship between 'air temperature' and 'process temperature'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Air temperature [K]', y='Process temperature [K]', data=df, hue='Target')
plt.title("Air Temperature vs. Process Temperature")
plt.xlabel("Air Temperature [K]")
plt.ylabel("Process Temperature [K]")
plt.show()

# %%
print(df.head())
print(df.head())
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
# 3                298.2                    308.6                    1433
# 4                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target  Type_L  Type_M  \
# 0         42.8                0       0       0       1
# 1         46.3                3       0       1       0
# 2         49.4                5       0       1       0
# 3         39.5                7       0       1       0
# 4         40.0                9       0       1       0
#
#    Failure Type_No Failure  Failure Type_Overstrain Failure  \
# 0                        1                                0
# 1                        1                                0
# ...

# %%
# Drop the 'Target' column from the features
X = df.drop(columns=['Target'])

# Keep only the failure type columns as the target
y = df[['Failure Type_No Failure', 'Failure Type_Overstrain Failure', 'Failure Type_Power Failure', 
        'Failure Type_Random Failures', 'Failure Type_Tool Wear Failure']]

# %%
print(x)
print("print y")
print(y)
# Out:
#       Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                   298.1                    308.6                    1551
# 1                   298.2                    308.7                    1408
# 2                   298.1                    308.5                    1498
# 3                   298.2                    308.6                    1433
# 4                   298.2                    308.7                    1408
# ...                   ...                      ...                     ...
# 9995                298.8                    308.4                    1604
# 9996                298.9                    308.4                    1632
# 9997                299.0                    308.6                    1645
# 9998                299.0                    308.7                    1408
# 9999                299.0                    308.7                    1500
#
#       Torque [Nm]  Tool wear [min]  Type_L  Type_M
# ...

# %%
from sklearn.model_selection import train_test_split
#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(X_train)
print(y_train)
# Out:
#       Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 9254                298.3                    309.1                    1616
# 1561                298.2                    308.4                    1388
# 1670                298.2                    307.8                    1528
# 6087                300.9                    310.8                    1599
# 6669                301.4                    310.5                    1571
# ...                   ...                      ...                     ...
# 5734                302.3                    311.8                    1369
# 5191                304.0                    313.2                    1416
# 5390                302.8                    312.3                    1483
# 860                 296.1                    306.9                    1541
# 7270                300.2                    310.4                    1808
#
#       Torque [Nm]  Tool wear [min]  Type_L  Type_M
# ...

# %%
#import all the libraries
import numpy as np
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
y_train_1d = np.argmax(y_train.values, axis=1)

# %%
# Initialize and train the Naive Bayes classifier
nb_clf = GaussianNB()
nb_clf.fit(X_train, y_train_1d)
# Out:
# GaussianNB()

# %%
# Convert y_test to a 1D array
y_test_1d = np.argmax(y_test.values, axis=1)

# Make predictions on the test set
y_pred_nb = nb_clf.predict(X_test)

# Evaluate the classifier's performance
accuracy_nb = accuracy_score(y_test_1d, y_pred_nb)
conf_matrix_nb = confusion_matrix(y_test_1d, y_pred_nb)

# %%
# Print results
print("Naive Bayes Accuracy:", accuracy_nb)
print("Naive Bayes Confusion Matrix:")
print(conf_matrix_nb)

# Visualize the predictions in a graph
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_nb, annot=True, cmap="Blues", fmt="d", cbar=False)
plt.title("Naive Bayes Confusion Matrix")
plt.show()
# Out:
# Naive Bayes Accuracy: 0.9585
# Naive Bayes Confusion Matrix:
# [[1900   25   23    0    2]
#  [   2   11    0    0    0]
#  [  12    2    6    0    0]
#  [   6    0    0    0    0]
#  [  11    0    0    0    0]]

# %%
# Initialize and train the Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train, y_train_1d)

# Make predictions on the test set
y_pred_rf = rf_clf.predict(X_test)

# Calculate accuracy
accuracy_rf = accuracy_score(y_test_1d, y_pred_rf)
print("Random Forest Accuracy:", accuracy_rf)

# Confusion Matrix
conf_matrix_rf = confusion_matrix(y_test_1d, y_pred_rf)
print("Confusion Matrix:")
print(conf_matrix_rf)

# Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_rf, annot=True, cmap="YlGnBu", fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Random Forest')
plt.show()
# Out:
# Random Forest Accuracy: 0.984
# Confusion Matrix:
# [[1946    0    4    0    0]
#  [   6    7    0    0    0]
#  [   4    1   15    0    0]
#  [   6    0    0    0    0]
#  [  11    0    0    0    0]]

# %%
# Initialize and train the Decision Tree classifier
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(X_train, y_train_1d)

# Make predictions on the test set
y_pred_dt = dt_clf.predict(X_test)

# Calculate accuracy
accuracy_dt = accuracy_score(y_test_1d, y_pred_dt)
print("Decision Tree Accuracy:", accuracy_dt)

# Confusion Matrix
conf_matrix_dt = confusion_matrix(y_test_1d, y_pred_dt)
print("Confusion Matrix:")
print(conf_matrix_dt)

# Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_dt, annot=True, cmap="YlGnBu", fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Decision Tree')
plt.show()
# Out:
# Decision Tree Accuracy: 0.9745
# Confusion Matrix:
# [[1925    4    6    4   11]
#  [   4    9    0    0    0]
#  [   5    1   14    0    0]
#  [   6    0    0    0    0]
#  [   9    1    0    0    1]]

# %%
# Initialize and train the SVM classifier
svm_clf = SVC(random_state=42)
svm_clf.fit(X_train, y_train_1d)

# Make predictions on the test set
y_pred_svm = svm_clf.predict(X_test)

# Calculate accuracy
accuracy_svm = accuracy_score(y_test_1d, y_pred_svm)
print("SVM Accuracy:", accuracy_svm)

# Confusion Matrix
conf_matrix_svm = confusion_matrix(y_test_1d, y_pred_svm)
print("Confusion Matrix:")
print(conf_matrix_svm)

# Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_svm, annot=True, cmap="YlGnBu", fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - SVM')
plt.show()
# Out:
# SVM Accuracy: 0.9755
# Confusion Matrix:
# [[1950    0    0    0    0]
#  [  13    0    0    0    0]
#  [  19    0    1    0    0]
#  [   6    0    0    0    0]
#  [  11    0    0    0    0]]

# %%
# Based on the provided confusion matrix and accuracy, it seems that the Random Forest classifier is performing quite well overall. Let's analyze its performance:

# Accuracy: The accuracy of the Random Forest classifier is 0.984 or 98.4%. This means that out of all the samples in the test set, the classifier correctly predicted the class label for approximately 98.4% of the samples.

# Confusion Matrix: The confusion matrix provides more detailed insights into the classifier's performance for each class.

# Class 1: It correctly predicted 1946 samples as Class 1 (True Positives) and 0 samples as other classes (True Negatives). There were 4 misclassifications (False Negatives) for Class 1.
# Class 2: It correctly predicted 7 samples as Class 2 (True Positives) and misclassified 6 samples as Class 1 (False Positives).
# Class 3: It correctly predicted 15 samples as Class 3 (True Positives) and misclassified 5 samples as Class 1 (False Positives) and 1 sample as Class 2 (False Positives).
# Class 4: It did not correctly predict any samples as Class 4 (False Negatives).
# Class 5: It did not correctly predict any samples as Class 5 (False Negatives).
# From the confusion matrix, we can see that the classifier is performing well for most of the classes, with high true positive counts for Class 1, Class 2, and Class 3. However, it struggles with Classes 4 and 5, as it did not correctly predict any samples for these classes.

# Overall, the high accuracy and good performance for most classes indicate that the Random Forest classifier is doing well on this dataset. However, it might be beneficial to investigate further and potentially improve the model's performance for Classes 4 and 5, if necessary. This could involve collecting more data for these classes, adjusting hyperparameters, or trying other classification algorithms.
